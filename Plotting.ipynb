# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
Y = np.random.random((10,1)) * 10

# %%
plt.plot(Y)

# %%
plt.plot(Y, "o")

# %%
plt.plot(Y, "o--")

# %%
x = np.linspace(0,10,100)
y = np.power(x, 0.5)

# %%
plt.plot(x,y,"--")

# %%
plt.plot(y,x,"--")

# %%
import seaborn as sns
sns.set()

# %%
sns.lineplot(y,x)

# %%
import pandas as pd

# %%
df = pd.read_csv("mobile_cleaned.csv")

# %%
df
# Out:
#      sim_type  aperture  gpu_rank  weight  stand_by_time  processor_frequency  \
# 0           0        12        55   155.0            250                  1.3
# 1           0         1        55   132.0            300                  1.3
# 2           0         9        55   142.0            329                  1.5
# 3           0         8        55   152.0            385                  1.3
# 4           1         1        55   234.0            385                  1.3
# ..        ...       ...       ...     ...            ...                  ...
# 104         3        10        14   192.0            540                  1.8
# 105         0         5         3   157.0            400                  2.3
# 106         3        10         6   192.0            384                  1.8
# 107         3        10        12   129.0            250                  1.4
# 108         2         8         3   158.0            400                  2.2
#
# ...

# %%
ax = sns.scatterplot(x="stand_by_time", y = "battery_capacity", data = df)

# %%
ax = sns.scatterplot(x = "stand_by_time", y= "battery_capacity", hue="thickness", size = "thickness", data =df)

# %%
ax = sns.distplot(df['stand_by_time'] , kde=False, rug=True, bins=30)

# %%
ax = sns.boxplot(x="is_liked", y = "battery_capacity", data = df)

# %%
ax = sns.boxplot(x = "expandable_memory", y = "price", data =df)

# %%
ax = sns.heatmap(df[['price', 'expandable_memory']])
